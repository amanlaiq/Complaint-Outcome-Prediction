# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Data Overview**
#
# We have gathered two key datasets to support our research and analysis. Below is a detailed breakdown of each dataset:
#
# ## 1. CCRB Dataset
#
# ### Dataset Source
# - **Origin:** Civilian Complaint Review Board (CCRB)
#
# ### Timeframe of Data
# - **Period:** 1985 - 2020
#
# ### Volume of Data
# - **Total Complaints:** 33,358
#
# ### Dataset Composition
# - The CCRB dataset is provided as a primary `.csv` file, along with an Excel file named `CCRB Data Layout Table`, which serves to clarify the terminology used within the dataset.
#
# ## 2. Additional Geospatial Data
#
# This dataset complements the first by providing geospatial information crucial for in-depth analysis and visualization.
#
# ### Dataset Composition
# - A shapefile dataset (`*.shp`) is included to facilitate precinct geolocation analysis, enhancing the exploratory data analysis (EDA) process.
#
# ### Accessibility
# - The dataset, along with the `.csv` file and the Excel terminology guide, is accessible through a provided link.
# - Precinct location data is derived from an exported shapefile (`.shp`), allowing for precise geographical mapping and analysis.
#
# ### Utilization
# - This geospatial dataset is pivotal for uncovering patterns and trends within the civilian complaints filed against NYPD officers. It enables a spatial analysis approach, augmenting the predictive modeling of outcomes and fostering a deeper understanding of the impact of precinct locations on complaint frequencies and types.

# %%
# navigating to the dataset folder uploaded to google drive
# %cd "/content/drive/MyDrive/PoliceComplaintDataset"
# !pwd
# Out:
# /content/drive/MyDrive/PoliceComplaintDataset
# /content/drive/MyDrive/PoliceComplaintDataset

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
import random
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import geopandas as gpd
from matplotlib import pyplot
from geopy.geocoders import Nominatim
import datetime

# %%
#importing the dataset
df=pd.read_csv("allegations_202007271729.csv")
df.shape
# Out:
# (33358, 27)

# %%
df.head()
# Out:
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT       8409         42835
# 1          10007       John     Sears     078 PCT       5952         24601
# 2          10007       John     Sears     078 PCT       5952         24601
# 3          10007       John     Sears     078 PCT       5952         26146
# 4          10009      Noemi    Sierra     078 PCT      24058         40253
#
#    month_received  year_received  month_closed  year_closed  ...  \
# 0               7           2019             5         2020  ...
# 1              11           2011             8         2012  ...
# 2              11           2011             8         2012  ...
# 3               7           2012             9         2013  ...
# 4               8           2018             2         2019  ...
#
#   mos_age_incident complainant_ethnicity complainant_gender  \
# 0               32                 Black             Female
# 1               24                 Black               Male
# 2               24                 Black               Male
# 3               25                 Black               Male
# 4               39                   NaN                NaN
#
#   complainant_age_incident           fado_type                    allegation  \
# 0                     38.0  Abuse of Authority  Failure to provide RTKA card
# 1                     26.0         Discourtesy                        Action
# 2                     26.0  Offensive Language                          Race
# 3                     45.0  Abuse of Authority                      Question
# 4                     16.0               Force                Physical force
#
#   precinct                                contact_reason  \
# 0     78.0                       Report-domestic dispute
# 1     67.0                              Moving violation
# 2     67.0                              Moving violation
# 3     67.0  PD suspected C/V of violation/crime - street
# 4     67.0                                Report-dispute
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   shield_no                 33358 non-null  int64
#  5   complaint_id              33358 non-null  int64
#  6   month_received            33358 non-null  int64
#  7   year_received             33358 non-null  int64
#  8   month_closed              33358 non-null  int64
#  9   year_closed               33358 non-null  int64
#  10  command_at_incident       31814 non-null  object
#  11  rank_abbrev_incident      33358 non-null  object
#  12  rank_abbrev_now           33358 non-null  object
#  13  rank_now                  33358 non-null  object
#  14  rank_incident             33358 non-null  object
#  15  mos_ethnicity             33358 non-null  object
#  16  mos_gender                33358 non-null  object
#  17  mos_age_incident          33358 non-null  int64
#  18  complainant_ethnicity     28894 non-null  object
#  19  complainant_gender        29163 non-null  object
#  20  complainant_age_incident  28546 non-null  float64
#  21  fado_type                 33358 non-null  object
#  22  allegation                33357 non-null  object
#  23  precinct                  33334 non-null  float64
#  24  contact_reason            33159 non-null  object
#  25  outcome_description       33302 non-null  object
#  26  board_disposition         33358 non-null  object
# dtypes: float64(2), int64(8), object(17)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#        unique_mos_id     shield_no  complaint_id  month_received  \
# count   33358.000000  33358.000000  33358.000000    33358.000000
# mean    18169.912495   6451.608819  23905.058217        6.323551
# std      9566.316896   7945.641596  11954.434138        3.362951
# min         2.000000      0.000000    517.000000        1.000000
# 25%      9671.000000   1089.000000  13684.750000        3.000000
# 50%     19215.000000   3691.000000  25132.000000        6.000000
# 75%     25412.000000   7155.000000  34252.000000        9.000000
# max     36374.000000  31977.000000  43703.000000       12.000000
#
#        year_received  month_closed   year_closed  mos_age_incident  \
# count   33358.000000  33358.000000  33358.000000      33358.000000
# mean     2010.726782      6.470772   2011.525661         32.346873
# std         6.034725      3.343372      6.085907          6.040944
# min      1985.000000      1.000000   1985.000000         20.000000
# 25%      2007.000000      4.000000   2008.000000         28.000000
# 50%      2012.000000      6.000000   2013.000000         31.000000
# 75%      2016.000000      9.000000   2016.000000         36.000000
# max      2020.000000     12.000000   2020.000000         60.000000
#
#        complainant_age_incident      precinct
# count              28546.000000  33334.000000
# mean                  32.484201     64.365213
# std                   28.408963     31.451592
# min                -4301.000000      0.000000
# 25%                   23.000000     43.000000
# 50%                   30.000000     67.000000
# 75%                   41.000000     81.000000
# max                  101.000000   1000.000000

# %%
df.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now', 'shield_no',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# unique_mos_id                  0
# first_name                     0
# last_name                      0
# command_now                    0
# shield_no                      0
# complaint_id                   0
# month_received                 0
# year_received                  0
# month_closed                   0
# year_closed                    0
# command_at_incident         1544
# rank_abbrev_incident           0
# rank_abbrev_now                0
# rank_now                       0
# rank_incident                  0
# mos_ethnicity                  0
# mos_gender                     0
# mos_age_incident               0
# complainant_ethnicity       4464
# complainant_gender          4195
# complainant_age_incident    4812
# fado_type                      0
# allegation                     1
# precinct                      24
# contact_reason               199
# outcome_description           56
# board_disposition              0
# dtype: int64

# %% [markdown]
# # **Merging base dataset with latitude and longitude dataset**

# %%
location= gpd.read_file("geo_export_359d6e65-21a5-4212-a07f-e715385fc5bc.shp")
location = location.to_crs(4326)
location['longitude'] = location.centroid.x
location['latitude'] = location.centroid.y
df=df.merge(location, how='right', on='precinct')
# Out:
# <ipython-input-11-2ee30262bf62>:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   location['longitude'] = location.centroid.x
# <ipython-input-11-2ee30262bf62>:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   location['latitude'] = location.centroid.y

# %% [markdown]
# # **Adding an additional column and binning from data received and date closed**

# %%
df['date_received'] = pd.to_datetime(df['year_received'].astype(str) + '-' +
                                     df['month_received'].astype(str) + '-01')
df['date_closed'] = pd.to_datetime(df['year_closed'].astype(str) + '-' +
                                   df['month_closed'].astype(str) + '-01')
df['days_taken_to_resolve']=(df['date_closed']-df['date_received']).dt.days
df['bins_day']=np.floor(df['days_taken_to_resolve']/30)

# %%
df[['days_taken_to_resolve','bins_day']]
# Out:
#        days_taken_to_resolve  bins_day
# 0                        305      10.0
# 1                        305      10.0
# 2                        151       5.0
# 3                        151       5.0
# 4                        183       6.0
# ...                      ...       ...
# 33305                    122       4.0
# 33306                    153       5.0
# 33307                    181       6.0
# 33308                    334      11.0
# 33309                    334      11.0
#
# [33310 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now', 'shield_no',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition', 'shape_area', 'shape_leng', 'geometry',
#        'longitude', 'latitude', 'date_received', 'date_closed',
#        'days_taken_to_resolve', 'bins_day'],
#       dtype='object')

# %% [markdown]
# # **Preparing new dataset for EDA after merging with the location dataset**

# %%
import geopy
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderInsufficientPrivileges

graph_data = df.groupby(['precinct']).size().reset_index(name='frequency')
merged_data = location.merge(graph_data, how='right', on='precinct')
merged_data['latitude']=merged_data['latitude'].apply(str)
merged_data['longitude']=merged_data['longitude'].apply(str)
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut, GeocoderServiceError
import time

geolocator = Nominatim(user_agent="nypd", timeout=10)

def zipcode_of_location(row):
    location_str = f"{row['latitude']},{row['longitude']}"
    retries = 3
    for attempt in range(retries):
        try:
            location = geolocator.reverse(location_str)
            zipcode = location.raw.get('address', {}).get('postcode', '')
            return zipcode
        except (GeocoderTimedOut, GeocoderUnavailable) as e:
            print(f"Retrying... Attempt {attempt + 1} of {retries}")
            time.sleep(1)
        except Exception as e:
            print(f"Error: {e}")
            return None
    return None

merged_data['zipcode'] = merged_data.apply(zipcode_of_location, axis=1)
merged_data_sorted = merged_data.sort_values('frequency', ascending=False)
merged_data_sorted = merged_data_sorted.head()

# %%
merged_data_sorted
# Out:
#     precinct    shape_area     shape_leng  \
# 46      75.0  1.804941e+08  106337.879200
# 45      73.0  5.175437e+07   33000.209960
# 26      44.0  5.551179e+07   31464.134787
# 28      46.0  3.833342e+07   29392.712842
# 39      67.0  9.381497e+07   43255.869527
#
#                                              geometry           longitude  \
# 46  MULTIPOLYGON (((-73.85023 40.62332, -73.85023 ...  -73.87775660857048
# 45  POLYGON ((-73.90405 40.67922, -73.90349 40.678...  -73.91094655789068
# 26  POLYGON ((-73.90269 40.84458, -73.90271 40.844...   -73.9207952796168
# 28  POLYGON ((-73.89138 40.86170, -73.89142 40.861...  -73.90957642771251
# 39  POLYGON ((-73.90755 40.65119, -73.90849 40.650...  -73.93381756632431
#
#               latitude  frequency zipcode
# 46  40.665009662366174       2172   11208
# 45    40.6681587790829       1163   11212
# 26   40.83380611153094       1139   10452
# 28  40.852746440383804       1120   10453
# 39   40.64804204405852       1119   11203

# %% [markdown]
# # **Abbreviations**

# %%
xls = pd.ExcelFile('CCRB Data Layout Table.xlsx')
df_ranks = pd.read_excel(xls, 'Rank Abbrevs')
df_command = pd.read_excel(xls, 'Command Abbrevs')

# %%
rank_dict=dict(zip(df_ranks.Abbreviation,df_ranks.Rank))
command_dict=dict(zip(df_command.Abbreviation,df_command['Command Name']))

# %%
df['command_now'].value_counts()
# Out:
# command_now
# INT CIS    1412
# WARRSEC    1158
# NARCBBX     692
# DB CEIS     681
# 075 PCT     415
#            ...
# C A B         1
# CD IRS        1
# PB HRD        1
# C/PRV D       1
# TRN BUR       1
# Name: count, Length: 415, dtype: int64

# %%
df['rank_abbrev_incident'].value_counts()
# Out:
# rank_abbrev_incident
# POM    19799
# SGT     5698
# DT3     2697
# POF     1397
# PO      1288
# LT      1262
# DTS      329
# DT2      193
# CPT      182
# SDS      128
# SSA      105
# DI        96
# DET       50
# INS       27
# LSA       24
# DT1       20
# LCD       13
# DC         2
# Name: count, dtype: int64

# %%
# Mapping the abbreviations to command names in two columns of a dataframe
df['command_now'] = df['command_now'].map(command_dict)
df['command_at_incident'] = df['command_at_incident'].map(command_dict)

# Mapping the abbreviations to command names in two columns of a dataframe
df['rank_abbrev_incident'] = df['rank_abbrev_incident'].map(rank_dict)
df['rank_abbrev_now'] = df['rank_abbrev_now'].map(rank_dict)

# %%
df['command_now'].value_counts()
# Out:
# command_now
# Criminal Intelligence Section                       1412
# Warrant Section                                     1158
# Narcotics Borough Bronx                              692
# Organized Crime Investigation Division               681
# 075 Precinct                                         415
#                                                     ...
# Facilities Management Division                         2
# Chief of Department Investigation Review Section       1
# Emergency Operations Center                            1
# Crime Prevention Division                              1
# Community Affairs Bureau                               1
# Name: count, Length: 385, dtype: int64

# %%
df['rank_abbrev_incident'].value_counts()
# Out:
# rank_abbrev_incident
# Police Officer                    22484
# Sergeant                           5698
# Detective Grade 3                  2697
# Lieutenant                         1262
# Detective Specialist                329
# Detective Grade 2                   193
# Captain                             182
# Sergeant Detective Squad            128
# Sergeant Special Assignment         105
# Deputy Inspector                     96
# Inspector                            27
# Lieutenant Special Assignment        24
# Detective Grade 1                    20
# Lieutenant Commander Detective       13
# Deputy Chief                          2
# Name: count, dtype: int64

# %% [markdown]
# # **Dropping Columns**

# %%
df.drop(['rank_now','rank_incident','shield_no'],axis=1,inplace=True)

# %% [markdown]
# # **Removing NAs with number of rows < 200**

# %%
df.dropna(subset=['allegation','precinct','contact_reason','outcome_description'],axis=0,inplace=True,how='any')

# %% [markdown]
# # **Combining some categories and filling NAs with mean, percentile_random_value, and mode value**

# %%
df["complainant_ethnicity"]=np.where(
    ((df["complainant_ethnicity"]=="Unknown") | (df["complainant_ethnicity"]=="Other Race") | (df["complainant_ethnicity"]=="Refused")),
    "Not disclosed",
    df["complainant_ethnicity"]
)
df.complainant_ethnicity.value_counts()
# Out:
# complainant_ethnicity
# Black              17011
# Hispanic            6384
# White               2754
# Not disclosed       1957
# Asian                527
# American Indian       63
# Name: count, dtype: int64

# %%
df['complainant_gender'].value_counts()
# Out:
# complainant_gender
# Male                     23904
# Female                    4969
# Not described               57
# Transwoman (MTF)            20
# Transman (FTM)               5
# Gender non-conforming        2
# Name: count, dtype: int64

# %%
df['complainant_gender']=np.where(
    df['complainant_gender'].isna(),
    df['complainant_gender'].value_counts().index[0],
    df['complainant_gender']
)
df['complainant_gender'].value_counts()
# Out:
# complainant_gender
# Male                     28005
# Female                    4969
# Not described               57
# Transwoman (MTF)            20
# Transman (FTM)               5
# Gender non-conforming        2
# Name: count, dtype: int64

# %%
df['command_at_incident'].value_counts()
# Out:
# command_at_incident
# 075 Precinct                                 1360
# 046 Precinct                                  824
# 044 Precinct                                  754
# Narcotics Borough Brooklyn North              746
# 079 Precinct                                  735
#                                              ...
# Applicant Processing Division                   1
# 048 Detective Squad                             1
# 060 Precinct                                    1
# Detective Borough Queens South Operations       1
# 122 Detective Squad                             1
# Name: count, Length: 271, dtype: int64

# %%
top5_commands=df['command_at_incident'].value_counts(normalize=True)[0:5].index.to_list()
top5_commands_weights=df['command_at_incident'].value_counts(normalize=True)[0:5].to_list()
top5_commands_weights=list(normalize([top5_commands_weights],norm="l1")[0])
print(top5_commands)
print(top5_commands_weights)
# Out:
# ['075 Precinct', '046 Precinct', '044 Precinct', 'Narcotics Borough Brooklyn North', '079 Precinct']
# [0.30776193708983934, 0.18646752658972618, 0.17062683865127856, 0.16881647431545596, 0.16632722335369993]

# %%
randomSampleList = np.random.choice(top5_commands,df['command_at_incident'].isna().sum(),replace=True,p=top5_commands_weights)
df['command_at_incident'].fillna(pd.Series(randomSampleList,index=df['command_at_incident'].index
                                           [df['command_at_incident'].isna()]), inplace=True)

# %%
df['command_at_incident'].value_counts()
# Out:
# command_at_incident
# 075 Precinct                        2222
# 046 Precinct                        1422
# 044 Precinct                        1278
# 079 Precinct                        1257
# Narcotics Borough Brooklyn North    1239
#                                     ...
# Emergency Service Squad 06             1
# 084 Detective Squad                    1
# OMAP                                   1
# Gang Division                          1
# 122 Detective Squad                    1
# Name: count, Length: 271, dtype: int64

# %% [markdown]
# # **Combining column and dropping original columns**

# %%
df['name']=df['first_name']+" "+df['last_name']
df.drop(['first_name','last_name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    unique_mos_id   command_now  complaint_id  month_received  year_received  \
# 0          10134  079 Precinct         24367              10           2011
# 1          10134  079 Precinct         24367              10           2011
# 2          10134  079 Precinct         26826              10           2012
# 3          10134  079 Precinct         26826              10           2012
# 4          10134  079 Precinct         32585               4           2015
#
#    month_closed  year_closed command_at_incident rank_abbrev_incident  \
# 0             8         2012        001 Precinct       Police Officer
# 1             8         2012        001 Precinct       Police Officer
# 2             3         2013        001 Precinct       Police Officer
# 3             3         2013        001 Precinct       Police Officer
# 4            10         2015        001 Precinct       Police Officer
#
#   rank_abbrev_now  ...    shape_area    shape_leng  \
# 0      Lieutenant  ...  4.728642e+07  80283.538778
# 1      Lieutenant  ...  4.728642e+07  80283.538778
# 2      Lieutenant  ...  4.728642e+07  80283.538778
# 3      Lieutenant  ...  4.728642e+07  80283.538778
# 4      Lieutenant  ...  4.728642e+07  80283.538778
#
#                                             geometry  longitude   latitude  \
# 0  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ... -74.012069  40.709791
# 1  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ... -74.012069  40.709791
# 2  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ... -74.012069  40.709791
# 3  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ... -74.012069  40.709791
# 4  MULTIPOLYGON (((-74.04388 40.69019, -74.04351 ... -74.012069  40.709791
#
#    date_received date_closed days_taken_to_resolve  bins_day        name
# 0     2011-10-01  2012-08-01                   305      10.0  James Hart
# 1     2011-10-01  2012-08-01                   305      10.0  James Hart
# 2     2012-10-01  2013-03-01                   151       5.0  James Hart
# 3     2012-10-01  2013-03-01                   151       5.0  James Hart
# 4     2015-04-01  2015-10-01                   183       6.0  James Hart
#
# [5 rows x 32 columns]

# %%
print(df.describe())
# Out:
#        unique_mos_id  complaint_id  month_received  year_received  \
# count   33058.000000  33058.000000    33058.000000   33058.000000
# mean    18166.338466  23933.525380        6.322554    2010.749440
# min         2.000000    517.000000        1.000000    1985.000000
# 25%      9671.000000  13788.000000        3.000000    2007.000000
# 50%     19211.500000  25142.000000        6.000000    2012.000000
# 75%     25412.000000  34222.000000        9.000000    2016.000000
# max     36374.000000  43703.000000       12.000000    2020.000000
# std      9564.189515  11898.461739        3.360411       5.997266
#
#        month_closed   year_closed  mos_age_incident  complainant_age_incident  \
# count  33058.000000  33058.000000      33058.000000              28342.000000
# mean       6.475195   2011.548067         32.350596                 32.467433
# min        1.000000   1985.000000         20.000000              -4301.000000
# 25%        4.000000   2008.000000         28.000000                 23.000000
# 50%        6.000000   2013.000000         31.000000                 30.000000
# 75%        9.000000   2016.000000         36.000000                 41.000000
# max       12.000000   2020.000000         58.000000                101.000000
# std        3.344758      6.050138          6.033642                 28.484648
#
#            precinct    shape_area     shape_leng     longitude      latitude  \
# count  33058.000000  3.305800e+04   33058.000000  33058.000000  33058.000000
# mean      64.368474  1.039859e+08   62197.469509    -73.919539     40.731712
# min        1.000000  1.529402e+07   17106.149405    -74.205858     40.536822
# 25%       43.000000  4.265745e+07   31464.134787    -73.949185     40.665010
# 50%       68.000000  6.213128e+07   44419.962668    -73.920795     40.703674
# 75%       81.000000  1.328626e+08   80619.597423    -73.877757     40.819275
# max      123.000000  4.755776e+08  308985.506998    -73.736833     40.892452
# std       30.169293  9.686088e+07   47058.246945      0.073226      0.087777
#
#                        date_received                    date_closed  \
# count                          33058                          33058
# mean   2011-03-11 20:56:52.475044096  2012-01-02 05:07:45.000907520
# min              1985-09-01 00:00:00            1985-09-01 00:00:00
# 25%              2007-06-01 00:00:00            2008-05-01 00:00:00
# 50%              2012-02-01 00:00:00            2013-04-01 00:00:00
# 75%              2016-01-01 00:00:00            2016-06-01 00:00:00
# max              2020-01-01 00:00:00            2020-06-01 00:00:00
# std                              NaN                            NaN
#
#        days_taken_to_resolve      bins_day
# count           33058.000000  33058.000000
# mean              296.340886      9.734678
# min                 0.000000      0.000000
# 25%               183.000000      6.000000
# 50%               303.000000     10.000000
# 75%               396.000000     13.000000
# max              3348.000000    111.000000
# std               152.756359      5.026902

# %%
ethnicity_contact_crosstab = pd.crosstab(df['contact_reason'], df['complainant_ethnicity'])
ethnicity_contact_crosstab
# Out:
# complainant_ethnicity                               American Indian  Asian  \
# contact_reason
# Aided case                                                        0      4
# Arrest/Complainant                                                0      0
# Assist ACS or other agency                                        0      0
# C/V at PCT to file complaint of crime                             0      0
# C/V at PCT to obtain information                                  0      3
# C/V at PCT to retrieve property                                   0      3
# C/V intervened on behalf of/observed encounter ...                0     15
# C/V requested info from officer                                   0      0
# C/V requested investigation of crime                              2      7
# C/V telephoned PCT                                                0      0
# CV already in custody                                             0      0
# Demonstration/protest                                             0      1
# EDP Aided Cases                                                   0      0
# EDP aided case                                                    1     14
# Execution of arrest/bench warrant                                 0      0
# Execution of search warrant                                       0      6
# Moving violation                                                  9     92
# No contact                                                        0      0
# Other                                                            18     43
# Other violation of VTL                                            3     24
# Others                                                            0      0
# PD auto checkpoint                                                0      0
# PD suspected C/V of violation/crime - auto                        2     66
# PD suspected C/V of violation/crime - bldg                       14     22
# PD suspected C/V of violation/crime - street                     11    107
# PD suspected C/V of violation/crime - subway                      0      9
# PD telephones CV                                                  0      0
# Parade/special event                                              0      1
# Parking violation                                                 0     10
# Patrol Encounter                                                  0      5
# Regulatory inspection                                             0      0
# Report of Disturbance/Noise Complaint                             0      0
# Report of other crime                                             0      8
# Report-dispute                                                    0     55
# Report-domestic dispute                                           2     14
# Report-gun possession/shots fired                                 0      5
# Report-noise/disturbance                                          0      2
# Report-possession/sale of narcotics                               1      0
# Stop/Question/Frisk                                               0      0
# Traffic Incidents/Accident/Prk Violation                          0      0
# Traffic accident                                                  0      9
# Transit checkpoint                                                0      2
#
# complainant_ethnicity                               Black  Hispanic  \
# contact_reason
# Aided case                                             65        26
# Arrest/Complainant                                      2         0
# Assist ACS or other agency                             27         0
# C/V at PCT to file complaint of crime                  46        28
# C/V at PCT to obtain information                       85        35
# C/V at PCT to retrieve property                        15        10
# C/V intervened on behalf of/observed encounter ...    272       124
# C/V requested info from officer                        45        19
# C/V requested investigation of crime                  133        54
# C/V telephoned PCT                                     74        43
# CV already in custody                                  33        28
# Demonstration/protest                                   5         2
# EDP Aided Cases                                         2         0
# EDP aided case                                         81        43
# Execution of arrest/bench warrant                     255        88
# Execution of search warrant                           343       113
# Moving violation                                     1079       377
# No contact                                              1         0
# Other                                                2212       768
# Other violation of VTL                                675       301
# Others                                                 12         0
# PD auto checkpoint                                     28         2
# PD suspected C/V of violation/crime - auto           1797       594
# PD suspected C/V of violation/crime - bldg           1322       522
# PD suspected C/V of violation/crime - street         6108      2190
# PD suspected C/V of violation/crime - subway          192        81
# PD telephones CV                                        2         4
# Parade/special event                                   15         7
# Parking violation                                     335       143
# Patrol Encounter                                        5         0
# Regulatory inspection                                  17         4
# Report of Disturbance/Noise Complaint                   0         0
# Report of other crime                                 402       171
# Report-dispute                                        443       199
# Report-domestic dispute                               223       124
# Report-gun possession/shots fired                     281        66
# Report-noise/disturbance                              145        90
# Report-possession/sale of narcotics                   145        85
# Stop/Question/Frisk                                     4         0
# Traffic Incidents/Accident/Prk Violation                1         0
# Traffic accident                                       81        41
# Transit checkpoint                                      3         2
#
# complainant_ethnicity                               Not disclosed  White
# contact_reason
# Aided case                                                     10     26
# Arrest/Complainant                                              0      0
# Assist ACS or other agency                                      1      0
# C/V at PCT to file complaint of crime                           7     16
# C/V at PCT to obtain information                               14     24
# C/V at PCT to retrieve property                                 2      6
# C/V intervened on behalf of/observed encounter ...             48     52
# C/V requested info from officer                                23     19
# C/V requested investigation of crime                           31     66
# C/V telephoned PCT                                             25     16
# CV already in custody                                           2     31
# Demonstration/protest                                           9     16
# EDP Aided Cases                                                 0      0
# EDP aided case                                                 61     56
# Execution of arrest/bench warrant                              13     22
# Execution of search warrant                                    43     15
# Moving violation                                              109    267
# No contact                                                      0      0
# Other                                                         323    406
# Other violation of VTL                                         48     54
# Others                                                          0      2
# PD auto checkpoint                                              4      5
# PD suspected C/V of violation/crime - auto                    181    267
# PD suspected C/V of violation/crime - bldg                    129    119
# PD suspected C/V of violation/crime - street                  494    698
# PD suspected C/V of violation/crime - subway                   29     62
# PD telephones CV                                                3      2
# Parade/special event                                            1     15
# Parking violation                                              54     81
# Patrol Encounter                                                0      0
# Regulatory inspection                                           6      2
# Report of Disturbance/Noise Complaint                           0      3
# Report of other crime                                          75     86
# Report-dispute                                                 99    148
# Report-domestic dispute                                        42     60
# Report-gun possession/shots fired                              15     25
# Report-noise/disturbance                                       14     26
# Report-possession/sale of narcotics                            23     17
# Stop/Question/Frisk                                             0      0
# Traffic Incidents/Accident/Prk Violation                        0      0
# Traffic accident                                               19     42
# Transit checkpoint                                              0      2

# %%
ethnicity_outcome_crosstab = pd.crosstab(df['outcome_description'], df['complainant_ethnicity'])
ethnicity_outcome_crosstab
# Out:
# complainant_ethnicity                 American Indian  Asian  Black  Hispanic  \
# outcome_description
# Arrest - OGA                                        0     12    420       100
# Arrest - assault (against a PO)                     0      8    546       139
# Arrest - disorderly conduct                         0      7    592       249
# Arrest - harrassment (against a PO)                 0      0      8         0
# Arrest - other violation/crime                      8    121   5379      2128
# Arrest - resisting arrest                           0     25    888       373
# Juvenile Report                                     0      0     35         6
# Moving violation summons issued                     2     54    389       149
# No arrest made or summons issued                   33    215   6072      2174
# Other VTL violation summons issued                  7      7    266       155
# Parking summons issued                              0     11    148        58
# Summons - OGA                                       0      0      1         0
# Summons - disorderly conduct                       10     29   1233       476
# Summons - harrassment (against a PO)                0      0      1         4
# Summons - other violation/crime                     3     38   1033       373
#
# complainant_ethnicity                 Not disclosed  White
# outcome_description
# Arrest - OGA                                     24     38
# Arrest - assault (against a PO)                  46     75
# Arrest - disorderly conduct                      41     70
# Arrest - harrassment (against a PO)               3      1
# Arrest - other violation/crime                  629    668
# Arrest - resisting arrest                        95    111
# Juvenile Report                                  15      0
# Moving violation summons issued                  50    159
# No arrest made or summons issued                764   1164
# Other VTL violation summons issued               34     48
# Parking summons issued                           29     26
# Summons - OGA                                     0      0
# Summons - disorderly conduct                    124    162
# Summons - harrassment (against a PO)              0      0
# Summons - other violation/crime                 103    232

# %%
rank_contact_crosstab = pd.crosstab(df['contact_reason'], df['rank_abbrev_incident'])
rank_contact_crosstab
# Out:
# rank_abbrev_incident                                Captain  Deputy Chief  \
# contact_reason
# Aided Cases                                               0             0
# Aided case                                                0             0
# Arrest/Complainant                                        0             0
# Arrest/Not Complainant                                    0             0
# Assist ACS or other agency                                0             0
# C/V at PCT to file complaint of crime                     5             0
# C/V at PCT to obtain information                          1             0
# C/V at PCT to retrieve property                           1             0
# C/V intervened on behalf of/observed encounter ...        1             0
# C/V requested info from officer                           0             0
# C/V requested investigation of crime                      0             0
# C/V telephoned PCT                                        0             0
# CV already in custody                                     0             0
# Complainant Witnessing Incident                           0             0
# Complainant at Pct. to make a Cmpl/info                   0             0
# Demonstration/protest                                     0             0
# Demonstrations                                            0             0
# Dispute                                                   0             0
# EDP Aided Cases                                           0             0
# EDP aided case                                            3             0
# Execution of arrest/bench warrant                         6             0
# Execution of search warrant                              38             0
# Moving violation                                          5             0
# No contact                                                0             0
# Other                                                    16             0
# Other violation of VTL                                    0             1
# Others                                                    1             0
# PD auto checkpoint                                        0             0
# PD suspected C/V of violation/crime - auto                5             0
# PD suspected C/V of violation/crime - bldg               20             0
# PD suspected C/V of violation/crime - street             41             0
# PD suspected C/V of violation/crime - subway              0             0
# PD telephones CV                                          0             0
# Parade/special event                                      6             0
# Parking violation                                         5             0
# Patrol Encounter                                          0             0
# Regulatory inspection                                     0             0
# Report of Crime Past/Present                              0             0
# Report of Disturbance/Noise Complaint                     0             0
# Report of other crime                                    11             0
# Report-dispute                                            1             0
# Report-domestic dispute                                   2             0
# Report-gun possession/shots fired                         4             1
# Report-noise/disturbance                                  7             0
# Report-possession/sale of narcotics                       3             0
# Stop/Question/Frisk                                       0             0
# Summons/Complainant                                       0             0
# Telephone Call to Precinct/Command                        0             0
# Traffic Incidents/Accident/Prk Violation                  0             0
# Traffic accident                                          0             0
# Transit checkpoint                                        0             0
# Vehicle Stop and Check                                    0             0
# Victim Subject of Sex Crime                               0             0
#
# rank_abbrev_incident                                Deputy Inspector  \
# contact_reason
# Aided Cases                                                        0
# Aided case                                                         0
# Arrest/Complainant                                                 0
# Arrest/Not Complainant                                             0
# Assist ACS or other agency                                         0
# C/V at PCT to file complaint of crime                              0
# C/V at PCT to obtain information                                   1
# C/V at PCT to retrieve property                                    0
# C/V intervened on behalf of/observed encounter ...                 0
# C/V requested info from officer                                    4
# C/V requested investigation of crime                               1
# C/V telephoned PCT                                                 0
# CV already in custody                                              1
# Complainant Witnessing Incident                                    0
# Complainant at Pct. to make a Cmpl/info                            0
# Demonstration/protest                                              0
# Demonstrations                                                     0
# Dispute                                                            0
# EDP Aided Cases                                                    0
# EDP aided case                                                     3
# Execution of arrest/bench warrant                                  0
# Execution of search warrant                                        6
# Moving violation                                                   6
# No contact                                                         0
# Other                                                              4
# Other violation of VTL                                             2
# Others                                                             0
# PD auto checkpoint                                                 0
# PD suspected C/V of violation/crime - auto                        13
# PD suspected C/V of violation/crime - bldg                        13
# PD suspected C/V of violation/crime - street                      23
# PD suspected C/V of violation/crime - subway                       0
# PD telephones CV                                                   0
# Parade/special event                                               0
# Parking violation                                                  0
# Patrol Encounter                                                   0
# Regulatory inspection                                              1
# Report of Crime Past/Present                                       0
# Report of Disturbance/Noise Complaint                              0
# Report of other crime                                              1
# Report-dispute                                                     0
# Report-domestic dispute                                            2
# Report-gun possession/shots fired                                 11
# Report-noise/disturbance                                           4
# Report-possession/sale of narcotics                                0
# Stop/Question/Frisk                                                0
# Summons/Complainant                                                0
# Telephone Call to Precinct/Command                                 0
# Traffic Incidents/Accident/Prk Violation                           0
# Traffic accident                                                   0
# Transit checkpoint                                                 0
# Vehicle Stop and Check                                             0
# Victim Subject of Sex Crime                                        0
#
# rank_abbrev_incident                                Detective Grade 1  \
# contact_reason
# Aided Cases                                                         0
# Aided case                                                          0
# Arrest/Complainant                                                  0
# Arrest/Not Complainant                                              0
# Assist ACS or other agency                                          0
# C/V at PCT to file complaint of crime                               0
# C/V at PCT to obtain information                                    0
# C/V at PCT to retrieve property                                     0
# C/V intervened on behalf of/observed encounter ...                  0
# C/V requested info from officer                                     0
# C/V requested investigation of crime                                0
# C/V telephoned PCT                                                  0
# CV already in custody                                               0
# Complainant Witnessing Incident                                     0
# Complainant at Pct. to make a Cmpl/info                             0
# Demonstration/protest                                               0
# Demonstrations                                                      0
# Dispute                                                             0
# EDP Aided Cases                                                     0
# EDP aided case                                                      0
# Execution of arrest/bench warrant                                   4
# Execution of search warrant                                         5
# Moving violation                                                    0
# No contact                                                          0
# Other                                                               2
# Other violation of VTL                                              0
# Others                                                              0
# PD auto checkpoint                                                  4
# PD suspected C/V of violation/crime - auto                          0
# PD suspected C/V of violation/crime - bldg                          5
# PD suspected C/V of violation/crime - street                        0
# PD suspected C/V of violation/crime - subway                        0
# PD telephones CV                                                    0
# Parade/special event                                                0
# Parking violation                                                   0
# Patrol Encounter                                                    0
# Regulatory inspection                                               0
# Report of Crime Past/Present                                        0
# Report of Disturbance/Noise Complaint                               0
# Report of other crime                                               0
# Report-dispute                                                      0
# Report-domestic dispute                                             0
# Report-gun possession/shots fired                                   0
# Report-noise/disturbance                                            0
# Report-possession/sale of narcotics                                 0
# Stop/Question/Frisk                                                 0
# Summons/Complainant                                                 0
# Telephone Call to Precinct/Command                                  0
# Traffic Incidents/Accident/Prk Violation                            0
# Traffic accident                                                    0
# Transit checkpoint                                                  0
# Vehicle Stop and Check                                              0
# Victim Subject of Sex Crime                                         0
#
# rank_abbrev_incident                                Detective Grade 2  \
# contact_reason
# Aided Cases                                                         0
# Aided case                                                          0
# Arrest/Complainant                                                  0
# Arrest/Not Complainant                                              0
# Assist ACS or other agency                                          1
# C/V at PCT to file complaint of crime                               0
# C/V at PCT to obtain information                                    0
# C/V at PCT to retrieve property                                     0
# C/V intervened on behalf of/observed encounter ...                  0
# C/V requested info from officer                                     0
# C/V requested investigation of crime                                0
# C/V telephoned PCT                                                  0
# CV already in custody                                               2
# Complainant Witnessing Incident                                     0
# Complainant at Pct. to make a Cmpl/info                             0
# Demonstration/protest                                               0
# Demonstrations                                                      0
# Dispute                                                             0
# EDP Aided Cases                                                     0
# EDP aided case                                                      0
# Execution of arrest/bench warrant                                  30
# Execution of search warrant                                        32
# Moving violation                                                   10
# No contact                                                          0
# Other                                                              31
# Other violation of VTL                                              0
# Others                                                              0
# PD auto checkpoint                                                  0
# PD suspected C/V of violation/crime - auto                          6
# PD suspected C/V of violation/crime - bldg                         10
# PD suspected C/V of violation/crime - street                       40
# PD suspected C/V of violation/crime - subway                        0
# PD telephones CV                                                    0
# Parade/special event                                                0
# Parking violation                                                   1
# Patrol Encounter                                                    0
# Regulatory inspection                                               0
# Report of Crime Past/Present                                        0
# Report of Disturbance/Noise Complaint                               0
# Report of other crime                                               4
# Report-dispute                                                      8
# Report-domestic dispute                                             6
# Report-gun possession/shots fired                                   0
# Report-noise/disturbance                                            0
# Report-possession/sale of narcotics                                 3
# Stop/Question/Frisk                                                 0
# Summons/Complainant                                                 0
# Telephone Call to Precinct/Command                                  0
# Traffic Incidents/Accident/Prk Violation                            0
# Traffic accident                                                    3
# Transit checkpoint                                                  0
# Vehicle Stop and Check                                              0
# Victim Subject of Sex Crime                                         0
#
# rank_abbrev_incident                                Detective Grade 3  \
# contact_reason
# Aided Cases                                                         0
# Aided case                                                          0
# Arrest/Complainant                                                  0
# Arrest/Not Complainant                                              0
# Assist ACS or other agency                                          3
# C/V at PCT to file complaint of crime                               9
# C/V at PCT to obtain information                                    3
# C/V at PCT to retrieve property                                     4
# C/V intervened on behalf of/observed encounter ...                 18
# C/V requested info from officer                                     2
# C/V requested investigation of crime                                7
# C/V telephoned PCT                                                 17
# CV already in custody                                               8
# Complainant Witnessing Incident                                     0
# Complainant at Pct. to make a Cmpl/info                             0
# Demonstration/protest                                               0
# Demonstrations                                                      0
# Dispute                                                             0
# EDP Aided Cases                                                     0
# EDP aided case                                                      0
# Execution of arrest/bench warrant                                 286
# Execution of search warrant                                       280
# Moving violation                                                   68
# No contact                                                          0
# Other                                                             314
# Other violation of VTL                                              7
# Others                                                              0
# PD auto checkpoint                                                  4
# PD suspected C/V of violation/crime - auto                        215
# PD suspected C/V of violation/crime - bldg                        210
# PD suspected C/V of violation/crime - street                     1036
# PD suspected C/V of violation/crime - subway                        3
# PD telephones CV                                                    4
# Parade/special event                                                0
# Parking violation                                                  22
# Patrol Encounter                                                    5
# Regulatory inspection                                               0
# Report of Crime Past/Present                                        0
# Report of Disturbance/Noise Complaint                               0
# Report of other crime                                              48
# Report-dispute                                                      9
# Report-domestic dispute                                            20
# Report-gun possession/shots fired                                  18
# Report-noise/disturbance                                            4
# Report-possession/sale of narcotics                                60
# Stop/Question/Frisk                                                 0
# Summons/Complainant                                                 0
# Telephone Call to Precinct/Command                                  0
# Traffic Incidents/Accident/Prk Violation                            0
# Traffic accident                                                    1
# Transit checkpoint                                                  0
# Vehicle Stop and Check                                              0
# Victim Subject of Sex Crime                                         0
#
# rank_abbrev_incident                                Detective Specialist  \
# contact_reason
# Aided Cases                                                            0
# Aided case                                                             4
# Arrest/Complainant                                                     0
# Arrest/Not Complainant                                                 0
# Assist ACS or other agency                                             0
# C/V at PCT to file complaint of crime                                  0
# C/V at PCT to obtain information                                       1
# C/V at PCT to retrieve property                                        0
# C/V intervened on behalf of/observed encounter ...                     3
# C/V requested info from officer                                        0
# C/V requested investigation of crime                                   5
# C/V telephoned PCT                                                     0
# CV already in custody                                                  7
# Complainant Witnessing Incident                                        0
# Complainant at Pct. to make a Cmpl/info                                0
# Demonstration/protest                                                  2
# Demonstrations                                                         0
# Dispute                                                                0
# EDP Aided Cases                                                        0
# EDP aided case                                                         4
# Execution of arrest/bench warrant                                      8
# Execution of search warrant                                           17
# Moving violation                                                      19
# No contact                                                             0
# Other                                                                 41
# Other violation of VTL                                                17
# Others                                                                 0
# PD auto checkpoint                                                     0
# PD suspected C/V of violation/crime - auto                            29
# PD suspected C/V of violation/crime - bldg                            25
# PD suspected C/V of violation/crime - street                          98
# PD suspected C/V of violation/crime - subway                           4
# PD telephones CV                                                       0
# Parade/special event                                                   0
# Parking violation                                                      4
# Patrol Encounter                                                       0
# Regulatory inspection                                                  2
# Report of Crime Past/Present                                           0
# Report of Disturbance/Noise Complaint                                  0
# Report of other crime                                                 19
# Report-dispute                                                         5
# Report-domestic dispute                                                1
# Report-gun possession/shots fired                                      5
# Report-noise/disturbance                                               3
# Report-possession/sale of narcotics                                    2
# Stop/Question/Frisk                                                    0
# Summons/Complainant                                                    0
# Telephone Call to Precinct/Command                                     0
# Traffic Incidents/Accident/Prk Violation                               0
# Traffic accident                                                       0
# Transit checkpoint                                                     0
# Vehicle Stop and Check                                                 0
# Victim Subject of Sex Crime                                            0
#
# rank_abbrev_incident                                Inspector  Lieutenant  \
# contact_reason
# Aided Cases                                                 0           0
# Aided case                                                  0           7
# Arrest/Complainant                                          0           2
# Arrest/Not Complainant                                      0           0
# Assist ACS or other agency                                  0           0
# C/V at PCT to file complaint of crime                       0           0
# C/V at PCT to obtain information                            0          12
# C/V at PCT to retrieve property                             0           1
# C/V intervened on behalf of/observed encounter ...          0          24
# C/V requested info from officer                             0           2
# C/V requested investigation of crime                        1          11
# C/V telephoned PCT                                          0           5
# CV already in custody                                       0           0
# Complainant Witnessing Incident                             0           0
# Complainant at Pct. to make a Cmpl/info                     0           0
# Demonstration/protest                                       0           2
# Demonstrations                                              0           0
# Dispute                                                     0           0
# EDP Aided Cases                                             0           0
# EDP aided case                                              0          22
# Execution of arrest/bench warrant                           2          30
# Execution of search warrant                                 6          50
# Moving violation                                            3          56
# No contact                                                  0           2
# Other                                                       2         123
# Other violation of VTL                                      0          33
# Others                                                      0          13
# PD auto checkpoint                                          0           2
# PD suspected C/V of violation/crime - auto                  0         112
# PD suspected C/V of violation/crime - bldg                  8         123
# PD suspected C/V of violation/crime - street                4         391
# PD suspected C/V of violation/crime - subway                0          15
# PD telephones CV                                            0           0
# Parade/special event                                        0           5
# Parking violation                                           0          11
# Patrol Encounter                                            0          10
# Regulatory inspection                                       0           9
# Report of Crime Past/Present                                0           1
# Report of Disturbance/Noise Complaint                       0           0
# Report of other crime                                       1          41
# Report-dispute                                              0          37
# Report-domestic dispute                                     0          27
# Report-gun possession/shots fired                           0          23
# Report-noise/disturbance                                    0          14
# Report-possession/sale of narcotics                         0          11
# Stop/Question/Frisk                                         0           4
# Summons/Complainant                                         0           3
# Telephone Call to Precinct/Command                          0           0
# Traffic Incidents/Accident/Prk Violation                    0           0
# Traffic accident                                            0          11
# Transit checkpoint                                          0           2
# Vehicle Stop and Check                                      0           2
# Victim Subject of Sex Crime                                 0           0
#
# rank_abbrev_incident                                Lieutenant Commander Detective  \
# contact_reason
# Aided Cases                                                                      0
# Aided case                                                                       0
# Arrest/Complainant                                                               0
# Arrest/Not Complainant                                                           0
# Assist ACS or other agency                                                       0
# C/V at PCT to file complaint of crime                                            0
# C/V at PCT to obtain information                                                 0
# C/V at PCT to retrieve property                                                  0
# C/V intervened on behalf of/observed encounter ...                               0
# C/V requested info from officer                                                  0
# C/V requested investigation of crime                                             0
# C/V telephoned PCT                                                               0
# CV already in custody                                                            1
# Complainant Witnessing Incident                                                  0
# Complainant at Pct. to make a Cmpl/info                                          0
# Demonstration/protest                                                            0
# Demonstrations                                                                   0
# Dispute                                                                          0
# EDP Aided Cases                                                                  0
# EDP aided case                                                                   0
# Execution of arrest/bench warrant                                                3
# Execution of search warrant                                                      2
# Moving violation                                                                 0
# No contact                                                                       0
# Other                                                                            0
# Other violation of VTL                                                           0
# Others                                                                           0
# PD auto checkpoint                                                               0
# PD suspected C/V of violation/crime - auto                                       3
# PD suspected C/V of violation/crime - bldg                                       4
# PD suspected C/V of violation/crime - street                                     0
# PD suspected C/V of violation/crime - subway                                     0
# PD telephones CV                                                                 0
# Parade/special event                                                             0
# Parking violation                                                                0
# Patrol Encounter                                                                 0
# Regulatory inspection                                                            0
# Report of Crime Past/Present                                                     0
# Report of Disturbance/Noise Complaint                                            0
# Report of other crime                                                            0
# Report-dispute                                                                   0
# Report-domestic dispute                                                          0
# Report-gun possession/shots fired                                                0
# Report-noise/disturbance                                                         0
# Report-possession/sale of narcotics                                              0
# Stop/Question/Frisk                                                              0
# Summons/Complainant                                                              0
# Telephone Call to Precinct/Command                                               0
# Traffic Incidents/Accident/Prk Violation                                         0
# Traffic accident                                                                 0
# Transit checkpoint                                                               0
# Vehicle Stop and Check                                                           0
# Victim Subject of Sex Crime                                                      0
#
# rank_abbrev_incident                                Lieutenant Special Assignment  \
# contact_reason
# Aided Cases                                                                     0
# Aided case                                                                      0
# Arrest/Complainant                                                              0
# Arrest/Not Complainant                                                          0
# Assist ACS or other agency                                                      0
# C/V at PCT to file complaint of crime                                           0
# C/V at PCT to obtain information                                                0
# C/V at PCT to retrieve property                                                 0
# C/V intervened on behalf of/observed encounter ...                              0
# C/V requested info from officer                                                 0
# C/V requested investigation of crime                                            0
# C/V telephoned PCT                                                              0
# CV already in custody                                                           0
# Complainant Witnessing Incident                                                 0
# Complainant at Pct. to make a Cmpl/info                                         0
# Demonstration/protest                                                           0
# Demonstrations                                                                  0
# Dispute                                                                         0
# EDP Aided Cases                                                                 0
# EDP aided case                                                                  0
# Execution of arrest/bench warrant                                               6
# Execution of search warrant                                                     0
# Moving violation                                                                8
# No contact                                                                      0
# Other                                                                           5
# Other violation of VTL                                                          0
# Others                                                                          0
# PD auto checkpoint                                                              0
# PD suspected C/V of violation/crime - auto                                      2
# PD suspected C/V of violation/crime - bldg                                      0
# PD suspected C/V of violation/crime - street                                    3
# PD suspected C/V of violation/crime - subway                                    0
# PD telephones CV                                                                0
# Parade/special event                                                            0
# Parking violation                                                               0
# Patrol Encounter                                                                0
# Regulatory inspection                                                           0
# Report of Crime Past/Present                                                    0
# Report of Disturbance/Noise Complaint                                           0
# Report of other crime                                                           0
# Report-dispute                                                                  0
# Report-domestic dispute                                                         0
# Report-gun possession/shots fired                                               0
# Report-noise/disturbance                                                        0
# Report-possession/sale of narcotics                                             0
# Stop/Question/Frisk                                                             0
# Summons/Complainant                                                             0
# Telephone Call to Precinct/Command                                              0
# Traffic Incidents/Accident/Prk Violation                                        0
# Traffic accident                                                                0
# Transit checkpoint                                                              0
# Vehicle Stop and Check                                                          0
# Victim Subject of Sex Crime                                                     0
#
# rank_abbrev_incident                                Police Officer  Sergeant  \
# contact_reason
# Aided Cases                                                     10         0
# Aided case                                                     130        13
# Arrest/Complainant                                              66         3
# Arrest/Not Complainant                                          30         2
# Assist ACS or other agency                                      19        13
# C/V at PCT to file complaint of crime                           57        30
# C/V at PCT to obtain information                                98        47
# C/V at PCT to retrieve property                                 20        13
# C/V intervened on behalf of/observed encounter ...             421        73
# C/V requested info from officer                                 82        22
# C/V requested investigation of crime                           243        46
# C/V telephoned PCT                                             114        38
# CV already in custody                                           53        22
# Complainant Witnessing Incident                                  4         1
# Complainant at Pct. to make a Cmpl/info                         13         3
# Demonstration/protest                                           23         8
# Demonstrations                                                   8         0
# Dispute                                                         96         8
# EDP Aided Cases                                                  8         4
# EDP aided case                                                 202        68
# Execution of arrest/bench warrant                              144       130
# Execution of search warrant                                    211       212
# Moving violation                                              1515       278
# No contact                                                       1         0
# Other                                                         2805       731
# Other violation of VTL                                         923       157
# Others                                                         140        10
# PD auto checkpoint                                              18        11
# PD suspected C/V of violation/crime - auto                    1889       693
# PD suspected C/V of violation/crime - bldg                    1604       467
# PD suspected C/V of violation/crime - street                  6684      1707
# PD suspected C/V of violation/crime - subway                   291        67
# PD telephones CV                                                 4         3
# Parade/special event                                            30         5
# Parking violation                                              520        72
# Patrol Encounter                                               314        28
# Regulatory inspection                                           15         7
# Report of Crime Past/Present                                   150        11
# Report of Disturbance/Noise Complaint                           34         2
# Report of other crime                                          626       148
# Report-dispute                                                 882       139
# Report-domestic dispute                                        434        65
# Report-gun possession/shots fired                              310       109
# Report-noise/disturbance                                       286        38
# Report-possession/sale of narcotics                            159        80
# Stop/Question/Frisk                                            162        29
# Summons/Complainant                                             33         3
# Telephone Call to Precinct/Command                              11         0
# Traffic Incidents/Accident/Prk Violation                       201        12
# Traffic accident                                               163        22
# Transit checkpoint                                               9         0
# Vehicle Stop and Check                                          48         1
# Victim Subject of Sex Crime                                      2         0
#
# rank_abbrev_incident                                Sergeant Detective Squad  \
# contact_reason
# Aided Cases                                                                0
# Aided case                                                                 0
# Arrest/Complainant                                                         0
# Arrest/Not Complainant                                                     0
# Assist ACS or other agency                                                 0
# C/V at PCT to file complaint of crime                                      0
# C/V at PCT to obtain information                                           0
# C/V at PCT to retrieve property                                            0
# C/V intervened on behalf of/observed encounter ...                         0
# C/V requested info from officer                                            0
# C/V requested investigation of crime                                       0
# C/V telephoned PCT                                                         1
# CV already in custody                                                      0
# Complainant Witnessing Incident                                            0
# Complainant at Pct. to make a Cmpl/info                                    0
# Demonstration/protest                                                      0
# Demonstrations                                                             0
# Dispute                                                                    0
# EDP Aided Cases                                                            0
# EDP aided case                                                             0
# Execution of arrest/bench warrant                                         28
# Execution of search warrant                                               43
# Moving violation                                                           0
# No contact                                                                 0
# Other                                                                      2
# Other violation of VTL                                                     0
# Others                                                                     0
# PD auto checkpoint                                                         0
# PD suspected C/V of violation/crime - auto                                 3
# PD suspected C/V of violation/crime - bldg                                21
# PD suspected C/V of violation/crime - street                              19
# PD suspected C/V of violation/crime - subway                               0
# PD telephones CV                                                           0
# Parade/special event                                                       0
# Parking violation                                                          0
# Patrol Encounter                                                           0
# Regulatory inspection                                                      0
# Report of Crime Past/Present                                               0
# Report of Disturbance/Noise Complaint                                      0
# Report of other crime                                                      3
# Report-dispute                                                             2
# Report-domestic dispute                                                    1
# Report-gun possession/shots fired                                          5
# Report-noise/disturbance                                                   0
# Report-possession/sale of narcotics                                        0
# Stop/Question/Frisk                                                        0
# Summons/Complainant                                                        0
# Telephone Call to Precinct/Command                                         0
# Traffic Incidents/Accident/Prk Violation                                   0
# Traffic accident                                                           0
# Transit checkpoint                                                         0
# Vehicle Stop and Check                                                     0
# Victim Subject of Sex Crime                                                0
#
# rank_abbrev_incident                                Sergeant Special Assignment
# contact_reason
# Aided Cases                                                                   0
# Aided case                                                                    0
# Arrest/Complainant                                                            0
# Arrest/Not Complainant                                                        0
# Assist ACS or other agency                                                    3
# C/V at PCT to file complaint of crime                                         1
# C/V at PCT to obtain information                                              2
# C/V at PCT to retrieve property                                               0
# C/V intervened on behalf of/observed encounter ...                            0
# C/V requested info from officer                                               0
# C/V requested investigation of crime                                          1
# C/V telephoned PCT                                                            0
# CV already in custody                                                         6
# Complainant Witnessing Incident                                               0
# Complainant at Pct. to make a Cmpl/info                                       0
# Demonstration/protest                                                         0
# Demonstrations                                                                0
# Dispute                                                                       0
# EDP Aided Cases                                                               0
# EDP aided case                                                                0
# Execution of arrest/bench warrant                                             0
# Execution of search warrant                                                  11
# Moving violation                                                              9
# No contact                                                                    0
# Other                                                                        17
# Other violation of VTL                                                        0
# Others                                                                        0
# PD auto checkpoint                                                            0
# PD suspected C/V of violation/crime - auto                                   11
# PD suspected C/V of violation/crime - bldg                                   12
# PD suspected C/V of violation/crime - street                                 21
# PD suspected C/V of violation/crime - subway                                  0
# PD telephones CV                                                              0
# Parade/special event                                                          0
# Parking violation                                                             0
# Patrol Encounter                                                              0
# Regulatory inspection                                                         0
# Report of Crime Past/Present                                                  0
# Report of Disturbance/Noise Complaint                                         0
# Report of other crime                                                         1
# Report-dispute                                                                1
# Report-domestic dispute                                                       3
# Report-gun possession/shots fired                                             6
# Report-noise/disturbance                                                      0
# Report-possession/sale of narcotics                                           0
# Stop/Question/Frisk                                                           0
# Summons/Complainant                                                           0
# Telephone Call to Precinct/Command                                            0
# Traffic Incidents/Accident/Prk Violation                                      0
# Traffic accident                                                              0
# Transit checkpoint                                                            0
# Vehicle Stop and Check                                                        0
# Victim Subject of Sex Crime                                                   0
